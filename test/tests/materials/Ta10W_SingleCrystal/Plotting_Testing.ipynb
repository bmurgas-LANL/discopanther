# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('method_Discoflux.csv')
e_2 = df['E_2'].to_numpy()
pk2_2 = df['pk2_2'].to_numpy()

print(max(pk2_2))

plt.figure()
plt.plot(np.abs(e_2),np.abs(pk2_2))
plt.grid()
plt.xlabel('Strain')
plt.ylabel('Stress (MPa)')
plt.show()
# Out:
# 320.19958710905
